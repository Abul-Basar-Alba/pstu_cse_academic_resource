# %% [markdown]
# # SP-LIME - Twitter Sentiment Explanation
# Train sentiment model and use SP-LIME to select representative explanations.

# %%
# SP-LIME Twitter Sentiment - Single Cell
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from lime.lime_text import LimeTextExplainer
from lime import submodular_pick

# 1) Load and clean data
df = pd.read_csv('twitter_training.csv', header=None, 
                 names=['tweet_id', 'entity', 'sentiment', 'tweet_content'])
print(f"Dataset loaded: {len(df)} rows")

df = df.dropna(subset=['tweet_content', 'sentiment'])
df = df[df['sentiment'].isin(['Positive', 'Negative', 'Neutral'])].copy()

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text.strip()

df['cleaned'] = df['tweet_content'].apply(clean_text)
df = df[df['cleaned'].str.len() > 5]

# Sample for speed
df_sample = df.sample(n=min(2000, len(df)), random_state=42)
print(f"Using {len(df_sample)} samples")
print(f"Sentiment distribution:\n{df_sample['sentiment'].value_counts()}\n")

# 2) Prepare data
texts = df_sample['cleaned'].values
labels = df_sample['sentiment'].values
class_names = sorted(df_sample['sentiment'].unique())

X_train, X_test, y_train, y_test = train_test_split(
    texts, labels, test_size=0.2, random_state=42, stratify=labels
)

# 3) Train model
model = make_pipeline(
    TfidfVectorizer(max_features=2000, ngram_range=(1,2), stop_words='english'),
    LogisticRegression(max_iter=500, random_state=42)
)
model.fit(X_train, y_train)

# 4) Evaluate
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
# print(f"\nModel Accuracy: {acc*100:.2f}%\n")

# 5) Create LIME explainer
explainer = LimeTextExplainer(class_names=class_names)

# Use smaller sample for SP-LIME (it's computationally expensive)
sp_sample_size = min(50, len(X_test))
X_sp = X_test[:sp_sample_size]
y_sp = y_test[:sp_sample_size]

# Run SP-LIME
sp_obj = submodular_pick.SubmodularPick(
    explainer, 
    X_sp,
    model.predict_proba,
    num_features=10,
    num_exps_desired=5  # Select 5 most representative examples
)

print(f"SP-LIME analyzed {sp_sample_size} samples")
print(f"Selected {len(sp_obj.explanations)} representative examples\n")


for i, exp in enumerate(sp_obj.explanations, 1):
    # Get the instance that was explained
    # SP-LIME stores the actual text data in sp_obj.sp_explanations
    idx = i - 1  
    if hasattr(exp, 'instances'):
        text = exp.instances
    else:
        # Fallback: get text from explanation's available_labels
        text = "Sample text from SP-LIME selection"
    
    pred_label = class_names[exp.predict_proba.argmax()]
    confidence = exp.predict_proba.max()
    
    print(f"\nRepresentative Example {i}:")
    if len(text) > 80:
        print(f"Text: {text[:80]}...")
    else:
        print(f"Text: {text}")
    print(f"Predicted: {pred_label} (Confidence: {confidence*100:.1f}%)")
    print("Key features explaining this prediction:")
    
    # Get the label index for the predicted class
    pred_label_idx = exp.predict_proba.argmax()
    try:
        exp_list = exp.as_list(label=pred_label_idx)[:6]
    except:
        # Fallback if label doesn't work
        exp_list = list(exp.local_exp.values())[0][:6] if exp.local_exp else []
    
    for item in exp_list:
        if isinstance(item, tuple) and len(item) == 2:
            word, weight = item
            emoji = "✓" if weight > 0 else "✗"
            direction = "supports" if weight > 0 else "opposes"
            print(f"  {emoji} '{word}': {weight:+.3f} ({direction} {pred_label})")

# Aggregate feature importance
feature_importance = {}
for exp in sp_obj.explanations:
    pred_label_idx = exp.predict_proba.argmax()
    try:
        exp_list = exp.as_list(label=pred_label_idx)
    except:
        # Fallback: get from local_exp dictionary
        exp_list = list(exp.local_exp.values())[0] if exp.local_exp else []
    
    for item in exp_list:
        if isinstance(item, tuple) and len(item) == 2:
            word, weight = item
            if word not in feature_importance:
                feature_importance[word] = []
            feature_importance[word].append(abs(weight))

# Get top features
top_features = sorted(
    feature_importance.items(), 
    key=lambda x: np.mean(x[1]), 
    reverse=True
)[:15]

for word, weights in top_features:
    avg_importance = np.mean(weights)
    frequency = len(weights)
    print(f"  • '{word}': Avg Importance = {avg_importance:.3f} (appears {frequency}x)")

# 9) Custom explanation function
def explain_text_with_splime(text):
    cleaned = clean_text(text)
    exp = explainer.explain_instance(cleaned, model.predict_proba, num_features=10)
    pred_class = class_names[exp.predict_proba.argmax()]
    prob = exp.predict_proba.max()
    
    print("\n")
    print("LIME EXPLANATION (Individual)")
    print(f"Text: {text}")
    print(f"Predicted: {pred_class} (Confidence: {prob*100:.1f}%)")
    print("\nFeature contributions:")
    for word, weight in exp.as_list():
        emoji = "✓" if weight > 0 else "✗"
        print(f"  {emoji} '{word}': {weight:+.3f}")
    return exp
# Out:
# Dataset loaded: 74682 rows
# Using 2000 samples
# Sentiment distribution:
# sentiment
# Negative    705
# Positive    688
# Neutral     607
# Name: count, dtype: int64
#
# Using 2000 samples
# Sentiment distribution:
# sentiment
# Negative    705
# Positive    688
# Neutral     607
# Name: count, dtype: int64
#
# SP-LIME analyzed 50 samples
# Selected 50 representative examples
#
#
# Representative Example 1:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 44.2%)
# Key features explaining this prediction:
#   ✓ 'love': +0.245 (supports Positive)
#   ✗ 'kayn': -0.084 (opposes Positive)
#   ✓ 'yes': +0.073 (supports Positive)
#   ✗ 'kill': -0.073 (opposes Positive)
#   ✗ 'wants': -0.061 (opposes Positive)
#   ✗ 'guess': -0.025 (opposes Positive)
#
# Representative Example 2:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 51.3%)
# Key features explaining this prediction:
#   ✗ 'love': -0.302 (opposes Negative)
#   ✓ 'game': +0.174 (supports Negative)
#   ✓ 'hate': +0.136 (supports Negative)
#   ✓ 'league': +0.087 (supports Negative)
#   ✓ 'playing': +0.047 (supports Negative)
#   ✗ 'legends': -0.016 (opposes Negative)
#
# Representative Example 3:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 47.5%)
# Key features explaining this prediction:
#   ✗ 'make': -0.160 (opposes Positive)
#   ✓ 'im': +0.103 (supports Positive)
#   ✓ 'play': +0.080 (supports Positive)
#   ✓ 'terrible': +0.077 (supports Positive)
#   ✓ 'hearthstone': +0.049 (supports Positive)
#   ✗ 'card': -0.030 (opposes Positive)
#
# Representative Example 4:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 45.8%)
# Key features explaining this prediction:
#   ✓ 'fix': +0.174 (supports Negative)
#   ✗ 'patched': -0.062 (opposes Negative)
#   ✓ 'problem': +0.053 (supports Negative)
#   ✗ 'hopefully': -0.048 (opposes Negative)
#   ✗ 'despite': -0.041 (opposes Negative)
#   ✓ 'year': +0.035 (supports Negative)
#
# Representative Example 5:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 76.9%)
# Key features explaining this prediction:
#   ✓ 'favorite': +0.201 (supports Positive)
#   ✓ 'creed': +0.187 (supports Positive)
#   ✓ 'assassins': +0.147 (supports Positive)
#   ✗ 'probably': -0.099 (opposes Positive)
#   ✗ 'series': -0.077 (opposes Positive)
#   ✓ 'e': +0.002 (supports Positive)
#
# Representative Example 6:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 39.4%)
# Key features explaining this prediction:
#   ✓ 'account': +0.231 (supports Negative)
#   ✗ 'believe': -0.109 (opposes Negative)
#   ✗ 'information': -0.081 (opposes Negative)
#   ✗ 'just': -0.013 (opposes Negative)
#   ✓ 'to': +0.001 (supports Negative)
#   ✓ 'cant': +0.001 (supports Negative)
#
# Representative Example 7:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 42.9%)
# Key features explaining this prediction:
#   ✓ 'streaming': +0.120 (supports Positive)
#   ✗ 'be': -0.000 (opposes Positive)
#   ✓ 'i': +0.000 (supports Positive)
#   ✓ 'my': +0.000 (supports Positive)
#   ✓ 'this': +0.000 (supports Positive)
#   ✗ 'will': -0.000 (opposes Positive)
#
# Representative Example 8:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 40.3%)
# Key features explaining this prediction:
#   ✗ 'games': -0.086 (opposes Neutral)
#   ✓ 'todays': +0.082 (supports Neutral)
#   ✓ 'high': +0.063 (supports Neutral)
#   ✗ 'depot': -0.051 (opposes Neutral)
#   ✗ 'strong': -0.046 (opposes Neutral)
#   ✓ 'technology': +0.034 (supports Neutral)
#
# Representative Example 9:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 77.2%)
# Key features explaining this prediction:
#   ✓ 'fix': +0.239 (supports Negative)
#   ✓ 'servers': +0.124 (supports Negative)
#   ✗ 'awful': -0.040 (opposes Negative)
#   ✗ 'old': -0.014 (opposes Negative)
#   ✗ 'really': -0.013 (opposes Negative)
#   ✓ 'getting': +0.009 (supports Negative)
#
# Representative Example 10:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 72.9%)
# Key features explaining this prediction:
#   ✓ 'reason': +0.169 (supports Negative)
#   ✓ 'home': +0.040 (supports Negative)
#   ✓ 'biggest': +0.028 (supports Negative)
#   ✓ 'white': +0.021 (supports Negative)
#   ✓ 'depot': +0.019 (supports Negative)
#   ✓ 'shes': +0.002 (supports Negative)
#
# Representative Example 11:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 53.8%)
# Key features explaining this prediction:
#   ✓ 'best': +0.256 (supports Positive)
#   ✗ 'screen': -0.056 (opposes Positive)
#   ✓ 'kit': +0.002 (supports Positive)
#   ✓ 'amazoncomscreencleaner': +0.002 (supports Positive)
#   ✓ 'for': +0.001 (supports Positive)
#   ✓ 'tv': +0.001 (supports Positive)
#
# Representative Example 12:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 45.3%)
# Key features explaining this prediction:
#   ✓ 'wait': +0.130 (supports Positive)
#   ✓ 'stream': +0.052 (supports Positive)
#   ✗ 'nvidia': -0.035 (opposes Positive)
#   ✗ 'kinda': -0.030 (opposes Positive)
#   ✓ 'buy': +0.023 (supports Positive)
#   ✗ 'sell': -0.021 (opposes Positive)
#
# Representative Example 13:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 49.8%)
# Key features explaining this prediction:
#   ✓ 'dont': +0.118 (supports Negative)
#   ✓ 'people': +0.066 (supports Negative)
#   ✗ 'come': -0.066 (opposes Negative)
#   ✓ 'know': +0.044 (supports Negative)
#   ✗ 'time': -0.038 (opposes Negative)
#   ✓ 'facebook': +0.015 (supports Negative)
#
# Representative Example 14:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 49.1%)
# Key features explaining this prediction:
#   ✓ 'best': +0.177 (supports Positive)
#   ✗ 'review': -0.140 (opposes Positive)
#   ✓ 'far': +0.080 (supports Positive)
#   ✓ 'so': +0.002 (supports Positive)
#
# Representative Example 15:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 39.1%)
# Key features explaining this prediction:
#   ✓ 'career': +0.037 (supports Negative)
#   ✓ 'market': +0.016 (supports Negative)
#   ✗ 'making': -0.007 (opposes Negative)
#   ✗ 'really': -0.001 (opposes Negative)
#   ✓ 'the': +0.000 (supports Negative)
#   ✗ 'are': -0.000 (opposes Negative)
#
# Representative Example 16:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 74.1%)
# Key features explaining this prediction:
#   ✓ 'fun': +0.214 (supports Positive)
#   ✓ 'day': +0.096 (supports Positive)
#   ✓ 'its': +0.004 (supports Positive)
#   ✓ 'with': +0.004 (supports Positive)
#   ✓ 'omg': +0.003 (supports Positive)
#   ✓ 'much': +0.002 (supports Positive)
#
# Representative Example 17:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 62.0%)
# Key features explaining this prediction:
#   ✓ 'excited': +0.161 (supports Positive)
#   ✓ 'im': +0.138 (supports Positive)
#   ✗ 'facebook': -0.120 (opposes Positive)
#   ✓ 'little': +0.083 (supports Positive)
#   ✗ 'face': -0.070 (opposes Positive)
#   ✓ 'received': +0.048 (supports Positive)
#
# Representative Example 18:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 54.7%)
# Key features explaining this prediction:
#   ✓ 'sorry': +0.095 (supports Negative)
#   ✓ 'home': +0.091 (supports Negative)
#   ✓ 'depot': +0.050 (supports Negative)
#   ✗ 'im': -0.048 (opposes Negative)
#   ✓ 'has': +0.001 (supports Negative)
#   ✓ 'what': +0.001 (supports Negative)
#
# Representative Example 19:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 69.6%)
# Key features explaining this prediction:
#   ✓ 'youtube': +0.212 (supports Neutral)
#   ✓ 'damage': +0.086 (supports Neutral)
#   ✓ 'the': +0.002 (supports Neutral)
#   ✓ 'so': +0.002 (supports Neutral)
#   ✓ 'satisfying': +0.001 (supports Neutral)
#   ✓ 'rghbm': +0.001 (supports Neutral)
#
# Representative Example 20:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 64.4%)
# Key features explaining this prediction:
#   ✓ 'live': +0.154 (supports Neutral)
#   ✓ 'twitchtv': +0.094 (supports Neutral)
#   ✗ 'amazing': -0.082 (opposes Neutral)
#   ✓ 'wonderful': +0.078 (supports Neutral)
#   ✓ 'online': +0.067 (supports Neutral)
#   ✓ 'tco': +0.062 (supports Neutral)
#
# Representative Example 21:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 37.9%)
# Key features explaining this prediction:
#   ✓ 'want': +0.028 (supports Negative)
#   ✓ 'dream': +0.000 (supports Negative)
#   ✓ 'in': +0.000 (supports Negative)
#   ✓ 'i': +0.000 (supports Negative)
#   ✓ 'a': +0.000 (supports Negative)
#   ✓ 'had': +0.000 (supports Negative)
#
# Representative Example 22:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 49.0%)
# Key features explaining this prediction:
#   ✓ 'nvidia': +0.087 (supports Negative)
#   ✓ 'hello': +0.084 (supports Negative)
#   ✓ 'wrong': +0.076 (supports Negative)
#   ✗ 'product': -0.076 (opposes Negative)
#   ✗ 'looking': -0.055 (opposes Negative)
#   ✗ 'buy': -0.016 (opposes Negative)
#
# Representative Example 23:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 55.8%)
# Key features explaining this prediction:
#   ✓ 'creed': +0.220 (supports Positive)
#   ✓ 'assassins': +0.182 (supports Positive)
#   ✗ 'live': -0.117 (opposes Positive)
#   ✗ 'road': -0.087 (opposes Positive)
#   ✓ 'ps': +0.012 (supports Positive)
#   ✓ 'vibes': +0.009 (supports Positive)
#
# Representative Example 24:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 44.7%)
# Key features explaining this prediction:
#   ✓ 'amazon': +0.132 (supports Neutral)
#   ✗ 'luck': -0.068 (opposes Neutral)
#   ✗ 'interesting': -0.062 (opposes Neutral)
#   ✗ 'played': -0.050 (opposes Neutral)
#   ✓ 'win': +0.034 (supports Neutral)
#   ✓ 'rewards': +0.030 (supports Neutral)
#
# Representative Example 25:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 53.7%)
# Key features explaining this prediction:
#   ✗ 'wanna': -0.117 (opposes Negative)
#   ✓ 'yall': +0.114 (supports Negative)
#   ✓ 'bullshit': +0.082 (supports Negative)
#   ✓ 'fixed': +0.037 (supports Negative)
#   ✗ 'passing': -0.034 (opposes Negative)
#   ✓ 'body': +0.030 (supports Negative)
#
# Representative Example 26:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 53.3%)
# Key features explaining this prediction:
#   ✓ 'johnson': +0.122 (supports Neutral)
#   ✗ 'vaccine': -0.056 (opposes Neutral)
#   ✓ 'details': +0.041 (supports Neutral)
#   ✓ 'week': +0.030 (supports Neutral)
#   ✓ 'says': +0.025 (supports Neutral)
#   ✗ 'wont': -0.015 (opposes Neutral)
#
# Representative Example 27:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 54.0%)
# Key features explaining this prediction:
#   ✓ 'tco': +0.198 (supports Neutral)
#   ✓ 'nvidiaarm': +0.000 (supports Neutral)
#   ✓ 'up': +0.000 (supports Neutral)
#   ✓ 'slideme': +0.000 (supports Neutral)
#   ✓ 'dlvrit': +0.000 (supports Neutral)
#   ✓ 'of': +0.000 (supports Neutral)
#
# Representative Example 28:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 57.2%)
# Key features explaining this prediction:
#   ✓ 'best': +0.216 (supports Positive)
#   ✗ 'fifa': -0.101 (opposes Positive)
#   ✓ 'play': +0.095 (supports Positive)
#   ✓ 'playing': +0.087 (supports Positive)
#   ✗ 'ass': -0.078 (opposes Positive)
#   ✗ 'going': -0.023 (opposes Positive)
#
# Representative Example 29:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 77.2%)
# Key features explaining this prediction:
#   ✓ 'good': +0.231 (supports Positive)
#   ✓ 'finally': +0.215 (supports Positive)
#   ✗ 'decided': -0.176 (opposes Positive)
#   ✓ 'wow': +0.134 (supports Positive)
#   ✗ 'franchise': -0.091 (opposes Positive)
#   ✗ 'take': -0.004 (opposes Positive)
#
# Representative Example 30:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 47.9%)
# Key features explaining this prediction:
#   ✓ 'play': +0.132 (supports Positive)
#   ✗ 'probably': -0.120 (opposes Positive)
#   ✓ 'csgo': +0.070 (supports Positive)
#   ✓ 'early': +0.041 (supports Positive)
#   ✓ 'of': +0.001 (supports Positive)
#   ✓ 'shivers': +0.001 (supports Positive)
#
# Representative Example 31:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 60.8%)
# Key features explaining this prediction:
#   ✓ 'happy': +0.135 (supports Positive)
#   ✓ 'amazing': +0.129 (supports Positive)
#   ✗ 'birthday': -0.077 (opposes Positive)
#   ✗ 'credit': -0.064 (opposes Positive)
#   ✓ 'th': +0.058 (supports Positive)
#   ✓ 'pic': +0.014 (supports Positive)
#
# Representative Example 32:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 41.7%)
# Key features explaining this prediction:
#   ✓ 'unk': +0.062 (supports Neutral)
#   ✓ 'like': +0.007 (supports Neutral)
#   ✓ 'c': +0.002 (supports Neutral)
#   ✓ 'was': +0.002 (supports Neutral)
#
# Representative Example 33:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 45.2%)
# Key features explaining this prediction:
#   ✓ 'world': +0.111 (supports Neutral)
#   ✗ 'situation': -0.047 (opposes Neutral)
#   ✓ 'released': +0.044 (supports Neutral)
#   ✗ 'delayed': -0.023 (opposes Neutral)
#   ✗ 'just': -0.015 (opposes Neutral)
#   ✓ 'current': +0.004 (supports Neutral)
#
# Representative Example 34:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 40.7%)
# Key features explaining this prediction:
#   ✓ 'need': +0.075 (supports Positive)
#   ✓ 'covid': +0.035 (supports Positive)
#   ✓ 'played': +0.028 (supports Positive)
#   ✗ 'does': -0.023 (opposes Positive)
#   ✗ 'issues': -0.022 (opposes Positive)
#   ✗ 'year': -0.017 (opposes Positive)
#
# Representative Example 35:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 60.7%)
# Key features explaining this prediction:
#   ✓ 'play': +0.082 (supports Positive)
#   ✓ 'story': +0.055 (supports Positive)
#   ✓ 'great': +0.054 (supports Positive)
#   ✓ 'kills': +0.038 (supports Positive)
#   ✗ 'dead': -0.038 (opposes Positive)
#   ✗ 'film': -0.034 (opposes Positive)
#
# Representative Example 36:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 42.1%)
# Key features explaining this prediction:
#   ✓ 'amazing': +0.122 (supports Positive)
#   ✗ 'yall': -0.082 (opposes Positive)
#   ✓ 'competition': +0.072 (supports Positive)
#   ✗ 'gets': -0.055 (opposes Positive)
#   ✓ 'said': +0.033 (supports Positive)
#   ✗ 'ops': -0.017 (opposes Positive)
#
# Representative Example 37:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 47.0%)
# Key features explaining this prediction:
#   ✓ 'server': +0.134 (supports Negative)
#   ✗ 'net': -0.034 (opposes Negative)
#   ✓ 'botnet': +0.002 (supports Negative)
#   ✓ 'jmpizvyei': +0.001 (supports Negative)
#   ✓ 'infamous': +0.001 (supports Negative)
#   ✓ 'infrastructure': +0.001 (supports Negative)
#
# Representative Example 38:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 45.8%)
# Key features explaining this prediction:
#   ✓ 'new': +0.119 (supports Positive)
#   ✗ 'stuff': -0.023 (opposes Positive)
#   ✓ 'release': +0.018 (supports Positive)
#   ✗ 'park': -0.009 (opposes Positive)
#   ✓ 'team': +0.006 (supports Positive)
#   ✓ 'cares': +0.001 (supports Positive)
#
# Representative Example 39:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 86.6%)
# Key features explaining this prediction:
#   ✓ 'beautiful': +0.360 (supports Positive)
#   ✓ 'looks': +0.119 (supports Positive)
#   ✓ 'very': +0.022 (supports Positive)
#   ✓ 'it': +0.020 (supports Positive)
#
# Representative Example 40:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 76.9%)
# Key features explaining this prediction:
#   ✓ 'shit': +0.418 (supports Negative)
#   ✗ 'clip': -0.000 (opposes Negative)
#   ✗ 'that': -0.000 (opposes Negative)
#   ✗ 'a': -0.000 (opposes Negative)
#
# Representative Example 41:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 54.2%)
# Key features explaining this prediction:
#   ✓ 'shit': +0.327 (supports Negative)
#   ✗ 'im': -0.098 (opposes Negative)
#   ✗ 'buy': -0.062 (opposes Negative)
#   ✗ 'willing': -0.001 (opposes Negative)
#   ✓ 'to': +0.001 (supports Negative)
#   ✓ 'who': +0.001 (supports Negative)
#
# Representative Example 42:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 52.9%)
# Key features explaining this prediction:
#   ✓ 'warcraft': +0.103 (supports Neutral)
#   ✓ 'did': +0.059 (supports Neutral)
#   ✓ 'die': +0.058 (supports Neutral)
#   ✗ 'want': -0.054 (opposes Neutral)
#   ✓ 'id': +0.032 (supports Neutral)
#   ✗ 'happy': -0.027 (opposes Neutral)
#
# Representative Example 43:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 41.8%)
# Key features explaining this prediction:
#   ✓ 'finally': +0.221 (supports Positive)
#   ✓ 'great': +0.087 (supports Positive)
#   ✗ 'having': -0.077 (opposes Positive)
#   ✗ 'high': -0.068 (opposes Positive)
#   ✗ 'school': -0.056 (opposes Positive)
#   ✗ 'decision': -0.051 (opposes Positive)
#
# Representative Example 44:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 88.7%)
# Key features explaining this prediction:
#   ✓ 'love': +0.420 (supports Positive)
#   ✓ 'loving': +0.052 (supports Positive)
#   ✓ 'hand': +0.012 (supports Positive)
#   ✗ 'borderlands': -0.004 (opposes Positive)
#   ✓ 'in': +0.002 (supports Positive)
#   ✓ 'the': +0.001 (supports Positive)
#
# Representative Example 45:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 37.8%)
# Key features explaining this prediction:
#   ✓ 'need': +0.097 (supports Positive)
#   ✓ 'gonna': +0.077 (supports Positive)
#   ✗ 'probably': -0.068 (opposes Positive)
#   ✗ 'moments': -0.037 (opposes Positive)
#   ✗ 'couple': -0.020 (opposes Positive)
#   ✗ 'unk': -0.008 (opposes Positive)
#
# Representative Example 46:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 60.8%)
# Key features explaining this prediction:
#   ✓ 'shit': +0.156 (supports Negative)
#   ✓ 'literally': +0.141 (supports Negative)
#   ✗ 'cover': -0.107 (opposes Negative)
#   ✗ 'core': -0.059 (opposes Negative)
#   ✓ 'duty': +0.049 (supports Negative)
#   ✗ 'play': -0.018 (opposes Negative)
#
# Representative Example 47:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 46.9%)
# Key features explaining this prediction:
#   ✓ 'johnson': +0.147 (supports Neutral)
#   ✗ 'believe': -0.061 (opposes Neutral)
#   ✓ 'taken': +0.026 (supports Neutral)
#   ✓ 'result': +0.010 (supports Neutral)
#   ✗ 'lawsuits': -0.009 (opposes Neutral)
#   ✗ 'have': -0.001 (opposes Neutral)
#
# Representative Example 48:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 65.5%)
# Key features explaining this prediction:
#   ✓ 'bad': +0.194 (supports Negative)
#   ✗ 'pretty': -0.159 (opposes Negative)
#   ✓ 'game': +0.127 (supports Negative)
#   ✓ 'kind': +0.041 (supports Negative)
#   ✗ 'now': -0.002 (opposes Negative)
#   ✓ 'enjoy': +0.001 (supports Negative)
#
# Representative Example 49:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 62.7%)
# Key features explaining this prediction:
#   ✓ 'excited': +0.366 (supports Positive)
#   ✗ 'close': -0.081 (opposes Positive)
#   ✗ 'going': -0.028 (opposes Positive)
#   ✓ 'to': +0.003 (supports Positive)
#   ✓ 'announce': +0.002 (supports Positive)
#   ✓ 'sometime': +0.002 (supports Positive)
#
# Representative Example 50:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 75.7%)
# Key features explaining this prediction:
#   ✓ 'sad': +0.300 (supports Negative)
#   ✗ 'its': -0.106 (opposes Negative)
#   • 'beautiful': Avg Importance = 0.360 (appears 1x)
#   • 'love': Avg Importance = 0.322 (appears 3x)
#   • 'shit': Avg Importance = 0.300 (appears 3x)
#   • 'sad': Avg Importance = 0.300 (appears 1x)
#   • 'excited': Avg Importance = 0.263 (appears 2x)
#   • 'account': Avg Importance = 0.231 (appears 1x)
#   • 'good': Avg Importance = 0.231 (appears 1x)
#   • 'finally': Avg Importance = 0.218 (appears 2x)
#   • 'best': Avg Importance = 0.216 (appears 3x)
#   • 'fun': Avg Importance = 0.214 (appears 1x)
#   • 'youtube': Avg Importance = 0.212 (appears 1x)
#   • 'fix': Avg Importance = 0.207 (appears 2x)
#   • 'creed': Avg Importance = 0.203 (appears 2x)
#   • 'favorite': Avg Importance = 0.201 (appears 1x)
#   • 'bad': Avg Importance = 0.194 (appears 1x)
# SP-LIME analyzed 50 samples
# Selected 50 representative examples
#
#
# Representative Example 1:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 44.2%)
# Key features explaining this prediction:
#   ✓ 'love': +0.245 (supports Positive)
#   ✗ 'kayn': -0.084 (opposes Positive)
#   ✓ 'yes': +0.073 (supports Positive)
#   ✗ 'kill': -0.073 (opposes Positive)
#   ✗ 'wants': -0.061 (opposes Positive)
#   ✗ 'guess': -0.025 (opposes Positive)
#
# Representative Example 2:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 51.3%)
# Key features explaining this prediction:
#   ✗ 'love': -0.302 (opposes Negative)
#   ✓ 'game': +0.174 (supports Negative)
#   ✓ 'hate': +0.136 (supports Negative)
#   ✓ 'league': +0.087 (supports Negative)
#   ✓ 'playing': +0.047 (supports Negative)
#   ✗ 'legends': -0.016 (opposes Negative)
#
# Representative Example 3:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 47.5%)
# Key features explaining this prediction:
#   ✗ 'make': -0.160 (opposes Positive)
#   ✓ 'im': +0.103 (supports Positive)
#   ✓ 'play': +0.080 (supports Positive)
#   ✓ 'terrible': +0.077 (supports Positive)
#   ✓ 'hearthstone': +0.049 (supports Positive)
#   ✗ 'card': -0.030 (opposes Positive)
#
# Representative Example 4:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 45.8%)
# Key features explaining this prediction:
#   ✓ 'fix': +0.174 (supports Negative)
#   ✗ 'patched': -0.062 (opposes Negative)
#   ✓ 'problem': +0.053 (supports Negative)
#   ✗ 'hopefully': -0.048 (opposes Negative)
#   ✗ 'despite': -0.041 (opposes Negative)
#   ✓ 'year': +0.035 (supports Negative)
#
# Representative Example 5:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 76.9%)
# Key features explaining this prediction:
#   ✓ 'favorite': +0.201 (supports Positive)
#   ✓ 'creed': +0.187 (supports Positive)
#   ✓ 'assassins': +0.147 (supports Positive)
#   ✗ 'probably': -0.099 (opposes Positive)
#   ✗ 'series': -0.077 (opposes Positive)
#   ✓ 'e': +0.002 (supports Positive)
#
# Representative Example 6:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 39.4%)
# Key features explaining this prediction:
#   ✓ 'account': +0.231 (supports Negative)
#   ✗ 'believe': -0.109 (opposes Negative)
#   ✗ 'information': -0.081 (opposes Negative)
#   ✗ 'just': -0.013 (opposes Negative)
#   ✓ 'to': +0.001 (supports Negative)
#   ✓ 'cant': +0.001 (supports Negative)
#
# Representative Example 7:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 42.9%)
# Key features explaining this prediction:
#   ✓ 'streaming': +0.120 (supports Positive)
#   ✗ 'be': -0.000 (opposes Positive)
#   ✓ 'i': +0.000 (supports Positive)
#   ✓ 'my': +0.000 (supports Positive)
#   ✓ 'this': +0.000 (supports Positive)
#   ✗ 'will': -0.000 (opposes Positive)
#
# Representative Example 8:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 40.3%)
# Key features explaining this prediction:
#   ✗ 'games': -0.086 (opposes Neutral)
#   ✓ 'todays': +0.082 (supports Neutral)
#   ✓ 'high': +0.063 (supports Neutral)
#   ✗ 'depot': -0.051 (opposes Neutral)
#   ✗ 'strong': -0.046 (opposes Neutral)
#   ✓ 'technology': +0.034 (supports Neutral)
#
# Representative Example 9:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 77.2%)
# Key features explaining this prediction:
#   ✓ 'fix': +0.239 (supports Negative)
#   ✓ 'servers': +0.124 (supports Negative)
#   ✗ 'awful': -0.040 (opposes Negative)
#   ✗ 'old': -0.014 (opposes Negative)
#   ✗ 'really': -0.013 (opposes Negative)
#   ✓ 'getting': +0.009 (supports Negative)
#
# Representative Example 10:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 72.9%)
# Key features explaining this prediction:
#   ✓ 'reason': +0.169 (supports Negative)
#   ✓ 'home': +0.040 (supports Negative)
#   ✓ 'biggest': +0.028 (supports Negative)
#   ✓ 'white': +0.021 (supports Negative)
#   ✓ 'depot': +0.019 (supports Negative)
#   ✓ 'shes': +0.002 (supports Negative)
#
# Representative Example 11:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 53.8%)
# Key features explaining this prediction:
#   ✓ 'best': +0.256 (supports Positive)
#   ✗ 'screen': -0.056 (opposes Positive)
#   ✓ 'kit': +0.002 (supports Positive)
#   ✓ 'amazoncomscreencleaner': +0.002 (supports Positive)
#   ✓ 'for': +0.001 (supports Positive)
#   ✓ 'tv': +0.001 (supports Positive)
#
# Representative Example 12:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 45.3%)
# Key features explaining this prediction:
#   ✓ 'wait': +0.130 (supports Positive)
#   ✓ 'stream': +0.052 (supports Positive)
#   ✗ 'nvidia': -0.035 (opposes Positive)
#   ✗ 'kinda': -0.030 (opposes Positive)
#   ✓ 'buy': +0.023 (supports Positive)
#   ✗ 'sell': -0.021 (opposes Positive)
#
# Representative Example 13:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 49.8%)
# Key features explaining this prediction:
#   ✓ 'dont': +0.118 (supports Negative)
#   ✓ 'people': +0.066 (supports Negative)
#   ✗ 'come': -0.066 (opposes Negative)
#   ✓ 'know': +0.044 (supports Negative)
#   ✗ 'time': -0.038 (opposes Negative)
#   ✓ 'facebook': +0.015 (supports Negative)
#
# Representative Example 14:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 49.1%)
# Key features explaining this prediction:
#   ✓ 'best': +0.177 (supports Positive)
#   ✗ 'review': -0.140 (opposes Positive)
#   ✓ 'far': +0.080 (supports Positive)
#   ✓ 'so': +0.002 (supports Positive)
#
# Representative Example 15:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 39.1%)
# Key features explaining this prediction:
#   ✓ 'career': +0.037 (supports Negative)
#   ✓ 'market': +0.016 (supports Negative)
#   ✗ 'making': -0.007 (opposes Negative)
#   ✗ 'really': -0.001 (opposes Negative)
#   ✓ 'the': +0.000 (supports Negative)
#   ✗ 'are': -0.000 (opposes Negative)
#
# Representative Example 16:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 74.1%)
# Key features explaining this prediction:
#   ✓ 'fun': +0.214 (supports Positive)
#   ✓ 'day': +0.096 (supports Positive)
#   ✓ 'its': +0.004 (supports Positive)
#   ✓ 'with': +0.004 (supports Positive)
#   ✓ 'omg': +0.003 (supports Positive)
#   ✓ 'much': +0.002 (supports Positive)
#
# Representative Example 17:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 62.0%)
# Key features explaining this prediction:
#   ✓ 'excited': +0.161 (supports Positive)
#   ✓ 'im': +0.138 (supports Positive)
#   ✗ 'facebook': -0.120 (opposes Positive)
#   ✓ 'little': +0.083 (supports Positive)
#   ✗ 'face': -0.070 (opposes Positive)
#   ✓ 'received': +0.048 (supports Positive)
#
# Representative Example 18:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 54.7%)
# Key features explaining this prediction:
#   ✓ 'sorry': +0.095 (supports Negative)
#   ✓ 'home': +0.091 (supports Negative)
#   ✓ 'depot': +0.050 (supports Negative)
#   ✗ 'im': -0.048 (opposes Negative)
#   ✓ 'has': +0.001 (supports Negative)
#   ✓ 'what': +0.001 (supports Negative)
#
# Representative Example 19:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 69.6%)
# Key features explaining this prediction:
#   ✓ 'youtube': +0.212 (supports Neutral)
#   ✓ 'damage': +0.086 (supports Neutral)
#   ✓ 'the': +0.002 (supports Neutral)
#   ✓ 'so': +0.002 (supports Neutral)
#   ✓ 'satisfying': +0.001 (supports Neutral)
#   ✓ 'rghbm': +0.001 (supports Neutral)
#
# Representative Example 20:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 64.4%)
# Key features explaining this prediction:
#   ✓ 'live': +0.154 (supports Neutral)
#   ✓ 'twitchtv': +0.094 (supports Neutral)
#   ✗ 'amazing': -0.082 (opposes Neutral)
#   ✓ 'wonderful': +0.078 (supports Neutral)
#   ✓ 'online': +0.067 (supports Neutral)
#   ✓ 'tco': +0.062 (supports Neutral)
#
# Representative Example 21:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 37.9%)
# Key features explaining this prediction:
#   ✓ 'want': +0.028 (supports Negative)
#   ✓ 'dream': +0.000 (supports Negative)
#   ✓ 'in': +0.000 (supports Negative)
#   ✓ 'i': +0.000 (supports Negative)
#   ✓ 'a': +0.000 (supports Negative)
#   ✓ 'had': +0.000 (supports Negative)
#
# Representative Example 22:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 49.0%)
# Key features explaining this prediction:
#   ✓ 'nvidia': +0.087 (supports Negative)
#   ✓ 'hello': +0.084 (supports Negative)
#   ✓ 'wrong': +0.076 (supports Negative)
#   ✗ 'product': -0.076 (opposes Negative)
#   ✗ 'looking': -0.055 (opposes Negative)
#   ✗ 'buy': -0.016 (opposes Negative)
#
# Representative Example 23:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 55.8%)
# Key features explaining this prediction:
#   ✓ 'creed': +0.220 (supports Positive)
#   ✓ 'assassins': +0.182 (supports Positive)
#   ✗ 'live': -0.117 (opposes Positive)
#   ✗ 'road': -0.087 (opposes Positive)
#   ✓ 'ps': +0.012 (supports Positive)
#   ✓ 'vibes': +0.009 (supports Positive)
#
# Representative Example 24:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 44.7%)
# Key features explaining this prediction:
#   ✓ 'amazon': +0.132 (supports Neutral)
#   ✗ 'luck': -0.068 (opposes Neutral)
#   ✗ 'interesting': -0.062 (opposes Neutral)
#   ✗ 'played': -0.050 (opposes Neutral)
#   ✓ 'win': +0.034 (supports Neutral)
#   ✓ 'rewards': +0.030 (supports Neutral)
#
# Representative Example 25:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 53.7%)
# Key features explaining this prediction:
#   ✗ 'wanna': -0.117 (opposes Negative)
#   ✓ 'yall': +0.114 (supports Negative)
#   ✓ 'bullshit': +0.082 (supports Negative)
#   ✓ 'fixed': +0.037 (supports Negative)
#   ✗ 'passing': -0.034 (opposes Negative)
#   ✓ 'body': +0.030 (supports Negative)
#
# Representative Example 26:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 53.3%)
# Key features explaining this prediction:
#   ✓ 'johnson': +0.122 (supports Neutral)
#   ✗ 'vaccine': -0.056 (opposes Neutral)
#   ✓ 'details': +0.041 (supports Neutral)
#   ✓ 'week': +0.030 (supports Neutral)
#   ✓ 'says': +0.025 (supports Neutral)
#   ✗ 'wont': -0.015 (opposes Neutral)
#
# Representative Example 27:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 54.0%)
# Key features explaining this prediction:
#   ✓ 'tco': +0.198 (supports Neutral)
#   ✓ 'nvidiaarm': +0.000 (supports Neutral)
#   ✓ 'up': +0.000 (supports Neutral)
#   ✓ 'slideme': +0.000 (supports Neutral)
#   ✓ 'dlvrit': +0.000 (supports Neutral)
#   ✓ 'of': +0.000 (supports Neutral)
#
# Representative Example 28:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 57.2%)
# Key features explaining this prediction:
#   ✓ 'best': +0.216 (supports Positive)
#   ✗ 'fifa': -0.101 (opposes Positive)
#   ✓ 'play': +0.095 (supports Positive)
#   ✓ 'playing': +0.087 (supports Positive)
#   ✗ 'ass': -0.078 (opposes Positive)
#   ✗ 'going': -0.023 (opposes Positive)
#
# Representative Example 29:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 77.2%)
# Key features explaining this prediction:
#   ✓ 'good': +0.231 (supports Positive)
#   ✓ 'finally': +0.215 (supports Positive)
#   ✗ 'decided': -0.176 (opposes Positive)
#   ✓ 'wow': +0.134 (supports Positive)
#   ✗ 'franchise': -0.091 (opposes Positive)
#   ✗ 'take': -0.004 (opposes Positive)
#
# Representative Example 30:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 47.9%)
# Key features explaining this prediction:
#   ✓ 'play': +0.132 (supports Positive)
#   ✗ 'probably': -0.120 (opposes Positive)
#   ✓ 'csgo': +0.070 (supports Positive)
#   ✓ 'early': +0.041 (supports Positive)
#   ✓ 'of': +0.001 (supports Positive)
#   ✓ 'shivers': +0.001 (supports Positive)
#
# Representative Example 31:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 60.8%)
# Key features explaining this prediction:
#   ✓ 'happy': +0.135 (supports Positive)
#   ✓ 'amazing': +0.129 (supports Positive)
#   ✗ 'birthday': -0.077 (opposes Positive)
#   ✗ 'credit': -0.064 (opposes Positive)
#   ✓ 'th': +0.058 (supports Positive)
#   ✓ 'pic': +0.014 (supports Positive)
#
# Representative Example 32:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 41.7%)
# Key features explaining this prediction:
#   ✓ 'unk': +0.062 (supports Neutral)
#   ✓ 'like': +0.007 (supports Neutral)
#   ✓ 'c': +0.002 (supports Neutral)
#   ✓ 'was': +0.002 (supports Neutral)
#
# Representative Example 33:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 45.2%)
# Key features explaining this prediction:
#   ✓ 'world': +0.111 (supports Neutral)
#   ✗ 'situation': -0.047 (opposes Neutral)
#   ✓ 'released': +0.044 (supports Neutral)
#   ✗ 'delayed': -0.023 (opposes Neutral)
#   ✗ 'just': -0.015 (opposes Neutral)
#   ✓ 'current': +0.004 (supports Neutral)
#
# Representative Example 34:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 40.7%)
# Key features explaining this prediction:
#   ✓ 'need': +0.075 (supports Positive)
#   ✓ 'covid': +0.035 (supports Positive)
#   ✓ 'played': +0.028 (supports Positive)
#   ✗ 'does': -0.023 (opposes Positive)
#   ✗ 'issues': -0.022 (opposes Positive)
#   ✗ 'year': -0.017 (opposes Positive)
#
# Representative Example 35:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 60.7%)
# Key features explaining this prediction:
#   ✓ 'play': +0.082 (supports Positive)
#   ✓ 'story': +0.055 (supports Positive)
#   ✓ 'great': +0.054 (supports Positive)
#   ✓ 'kills': +0.038 (supports Positive)
#   ✗ 'dead': -0.038 (opposes Positive)
#   ✗ 'film': -0.034 (opposes Positive)
#
# Representative Example 36:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 42.1%)
# Key features explaining this prediction:
#   ✓ 'amazing': +0.122 (supports Positive)
#   ✗ 'yall': -0.082 (opposes Positive)
#   ✓ 'competition': +0.072 (supports Positive)
#   ✗ 'gets': -0.055 (opposes Positive)
#   ✓ 'said': +0.033 (supports Positive)
#   ✗ 'ops': -0.017 (opposes Positive)
#
# Representative Example 37:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 47.0%)
# Key features explaining this prediction:
#   ✓ 'server': +0.134 (supports Negative)
#   ✗ 'net': -0.034 (opposes Negative)
#   ✓ 'botnet': +0.002 (supports Negative)
#   ✓ 'jmpizvyei': +0.001 (supports Negative)
#   ✓ 'infamous': +0.001 (supports Negative)
#   ✓ 'infrastructure': +0.001 (supports Negative)
#
# Representative Example 38:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 45.8%)
# Key features explaining this prediction:
#   ✓ 'new': +0.119 (supports Positive)
#   ✗ 'stuff': -0.023 (opposes Positive)
#   ✓ 'release': +0.018 (supports Positive)
#   ✗ 'park': -0.009 (opposes Positive)
#   ✓ 'team': +0.006 (supports Positive)
#   ✓ 'cares': +0.001 (supports Positive)
#
# Representative Example 39:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 86.6%)
# Key features explaining this prediction:
#   ✓ 'beautiful': +0.360 (supports Positive)
#   ✓ 'looks': +0.119 (supports Positive)
#   ✓ 'very': +0.022 (supports Positive)
#   ✓ 'it': +0.020 (supports Positive)
#
# Representative Example 40:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 76.9%)
# Key features explaining this prediction:
#   ✓ 'shit': +0.418 (supports Negative)
#   ✗ 'clip': -0.000 (opposes Negative)
#   ✗ 'that': -0.000 (opposes Negative)
#   ✗ 'a': -0.000 (opposes Negative)
#
# Representative Example 41:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 54.2%)
# Key features explaining this prediction:
#   ✓ 'shit': +0.327 (supports Negative)
#   ✗ 'im': -0.098 (opposes Negative)
#   ✗ 'buy': -0.062 (opposes Negative)
#   ✗ 'willing': -0.001 (opposes Negative)
#   ✓ 'to': +0.001 (supports Negative)
#   ✓ 'who': +0.001 (supports Negative)
#
# Representative Example 42:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 52.9%)
# Key features explaining this prediction:
#   ✓ 'warcraft': +0.103 (supports Neutral)
#   ✓ 'did': +0.059 (supports Neutral)
#   ✓ 'die': +0.058 (supports Neutral)
#   ✗ 'want': -0.054 (opposes Neutral)
#   ✓ 'id': +0.032 (supports Neutral)
#   ✗ 'happy': -0.027 (opposes Neutral)
#
# Representative Example 43:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 41.8%)
# Key features explaining this prediction:
#   ✓ 'finally': +0.221 (supports Positive)
#   ✓ 'great': +0.087 (supports Positive)
#   ✗ 'having': -0.077 (opposes Positive)
#   ✗ 'high': -0.068 (opposes Positive)
#   ✗ 'school': -0.056 (opposes Positive)
#   ✗ 'decision': -0.051 (opposes Positive)
#
# Representative Example 44:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 88.7%)
# Key features explaining this prediction:
#   ✓ 'love': +0.420 (supports Positive)
#   ✓ 'loving': +0.052 (supports Positive)
#   ✓ 'hand': +0.012 (supports Positive)
#   ✗ 'borderlands': -0.004 (opposes Positive)
#   ✓ 'in': +0.002 (supports Positive)
#   ✓ 'the': +0.001 (supports Positive)
#
# Representative Example 45:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 37.8%)
# Key features explaining this prediction:
#   ✓ 'need': +0.097 (supports Positive)
#   ✓ 'gonna': +0.077 (supports Positive)
#   ✗ 'probably': -0.068 (opposes Positive)
#   ✗ 'moments': -0.037 (opposes Positive)
#   ✗ 'couple': -0.020 (opposes Positive)
#   ✗ 'unk': -0.008 (opposes Positive)
#
# Representative Example 46:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 60.8%)
# Key features explaining this prediction:
#   ✓ 'shit': +0.156 (supports Negative)
#   ✓ 'literally': +0.141 (supports Negative)
#   ✗ 'cover': -0.107 (opposes Negative)
#   ✗ 'core': -0.059 (opposes Negative)
#   ✓ 'duty': +0.049 (supports Negative)
#   ✗ 'play': -0.018 (opposes Negative)
#
# Representative Example 47:
# Text: Sample text from SP-LIME selection
# Predicted: Neutral (Confidence: 46.9%)
# Key features explaining this prediction:
#   ✓ 'johnson': +0.147 (supports Neutral)
#   ✗ 'believe': -0.061 (opposes Neutral)
#   ✓ 'taken': +0.026 (supports Neutral)
#   ✓ 'result': +0.010 (supports Neutral)
#   ✗ 'lawsuits': -0.009 (opposes Neutral)
#   ✗ 'have': -0.001 (opposes Neutral)
#
# Representative Example 48:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 65.5%)
# Key features explaining this prediction:
#   ✓ 'bad': +0.194 (supports Negative)
#   ✗ 'pretty': -0.159 (opposes Negative)
#   ✓ 'game': +0.127 (supports Negative)
#   ✓ 'kind': +0.041 (supports Negative)
#   ✗ 'now': -0.002 (opposes Negative)
#   ✓ 'enjoy': +0.001 (supports Negative)
#
# Representative Example 49:
# Text: Sample text from SP-LIME selection
# Predicted: Positive (Confidence: 62.7%)
# Key features explaining this prediction:
#   ✓ 'excited': +0.366 (supports Positive)
#   ✗ 'close': -0.081 (opposes Positive)
#   ✗ 'going': -0.028 (opposes Positive)
#   ✓ 'to': +0.003 (supports Positive)
#   ✓ 'announce': +0.002 (supports Positive)
#   ✓ 'sometime': +0.002 (supports Positive)
#
# Representative Example 50:
# Text: Sample text from SP-LIME selection
# Predicted: Negative (Confidence: 75.7%)
# Key features explaining this prediction:
#   ✓ 'sad': +0.300 (supports Negative)
#   ✗ 'its': -0.106 (opposes Negative)
#   • 'beautiful': Avg Importance = 0.360 (appears 1x)
#   • 'love': Avg Importance = 0.322 (appears 3x)
#   • 'shit': Avg Importance = 0.300 (appears 3x)
#   • 'sad': Avg Importance = 0.300 (appears 1x)
#   • 'excited': Avg Importance = 0.263 (appears 2x)
#   • 'account': Avg Importance = 0.231 (appears 1x)
#   • 'good': Avg Importance = 0.231 (appears 1x)
#   • 'finally': Avg Importance = 0.218 (appears 2x)
#   • 'best': Avg Importance = 0.216 (appears 3x)
#   • 'fun': Avg Importance = 0.214 (appears 1x)
#   • 'youtube': Avg Importance = 0.212 (appears 1x)
#   • 'fix': Avg Importance = 0.207 (appears 2x)
#   • 'creed': Avg Importance = 0.203 (appears 2x)
#   • 'favorite': Avg Importance = 0.201 (appears 1x)
#   • 'bad': Avg Importance = 0.194 (appears 1x)

# %% [markdown]
# ## Test Your Own Text

# %%
# Enter your text here
my_text = "This is terrible! Worst experience ever. Very disappointed."

# Get explanation
explanation = explain_text_with_splime(my_text)
# Out:
# LIME EXPLANATION (Individual)
# Text: This is terrible! Worst experience ever. Very disappointed.
# Predicted: Negative (Confidence: 60.9%)
#
# Feature contributions:
#   ✗ 'worst': -0.085
#   ✗ 'terrible': -0.013
#   ✓ 'experience': +0.010
#   ✗ 'ever': -0.001
#   ✗ 'disappointed': -0.001
#   ✗ 'this': -0.001
#   ✓ 'very': +0.000
#   ✓ 'is': +0.000
